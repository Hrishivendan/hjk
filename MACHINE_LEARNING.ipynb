# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrishivendan/hjk/blob/main/MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path ='/content/drive/My Drive/Machine learning/IRIS.csv'

# %%
df=pd.read_csv(file_path)

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
features=['sepal_length','sepal_width','petal_length','petal_width']

# %%
for feature in features:
  plt.figure(figsize=(6,3))
  sns.scatterplot(x=df[feature],y=[8]*len(df),hue=df['species'],palette='deep')
  plt.title(f"Univarate scatter plot-{feature}")
  plt.xlabel(feature)
  plt.ylabel("constant(0)")
  plt.legend(title="species")
  plt.show()

# %%
bivariate_pairs=[
    ('sepal_width','petal_width'),
    ('sepal_length','petal_length')
]

# %%
for x_feature,y_feature in bivariate_pairs:
  plt.figure(figsize=(6,3))
  sns.scatterplot(x=df[x_feature],y=df[y_feature],hue=df['species'],palette='deep')
  plt.title(f"bivariate scatter plot-{x_feature} vs {y_feature}")
  plt.xlabel(x_feature)
  plt.ylabel(y_feature)
  plt.legend(title="species")
  plt.show()

# %%
df_features=df.drop(columns=['Id'],errors='ignore')

sns.pairplot(df_features,hue='species',palette='deep')
plt.suptitle("Multivariate Pairplot",y=1.02)
plt.show()
